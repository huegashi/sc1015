# %%
import shutil
source_path =r'C:\Users\MsNai\Downloads\sc1015\train.csv'
shutil.move(source_path, '.')
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# Cell In[4], line 3
#       1 import shutil
#       2 source_path =r'C:\Users\MsNai\Downloads\sc1015\train.csv'
# ----> 3 shutil.move(source_path, '.')
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\shutil.py:860, in move(src, dst, copy_function)
#     857     real_dst = os.path.join(dst, _basename(src))
#     859     if os.path.exists(real_dst):
# --> 860         raise Error("Destination path '%s' already exists" % real_dst)
#     861 try:
#     862     os.rename(src, real_dst)
#
# Error: Destination path '.\train.csv' already exists

# %%
import numpy as np
import pandas as pd

traindata = pd.read_csv(r'.\train.csv', header=None)
traindata
# Out:
#         0           1         2            3        4       5      6   \
# 0       Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley
# 1        1          60        RL           65     8450    Pave    NaN
# 2        2          20        RL           80     9600    Pave    NaN
# 3        3          60        RL           68    11250    Pave    NaN
# 4        4          70        RL           60     9550    Pave    NaN
# ...    ...         ...       ...          ...      ...     ...    ...
# 1456  1456          60        RL           62     7917    Pave    NaN
# 1457  1457          20        RL           85    13175    Pave    NaN
# 1458  1458          70        RL           66     9042    Pave    NaN
# 1459  1459          20        RL           68     9717    Pave    NaN
# 1460  1460          20        RL           75     9937    Pave    NaN
#
#             7            8          9   ...        71      72     73  \
# ...

# %%
traindata.shape
# Out:
# (1461, 81)

# %%
traindata.dtypes
# Out:
# 0     object
# 1     object
# 2     object
# 3     object
# 4     object
#        ...
# 76    object
# 77    object
# 78    object
# 79    object
# 80    object
# Length: 81, dtype: object

# %%
traindata.info
# Out:
# <bound method DataFrame.info of         0           1         2            3        4       5      6   \
# 0       Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley
# 1        1          60        RL           65     8450    Pave    NaN
# 2        2          20        RL           80     9600    Pave    NaN
# 3        3          60        RL           68    11250    Pave    NaN
# 4        4          70        RL           60     9550    Pave    NaN
# ...    ...         ...       ...          ...      ...     ...    ...
# 1456  1456          60        RL           62     7917    Pave    NaN
# 1457  1457          20        RL           85    13175    Pave    NaN
# 1458  1458          70        RL           66     9042    Pave    NaN
# 1459  1459          20        RL           68     9717    Pave    NaN
# 1460  1460          20        RL           75     9937    Pave    NaN
#
#             7            8          9   ...        71      72     73  \
# ...

# %%
traindata.describe
# Out:
# <bound method NDFrame.describe of         0           1         2            3        4       5      6   \
# 0       Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley
# 1        1          60        RL           65     8450    Pave    NaN
# 2        2          20        RL           80     9600    Pave    NaN
# 3        3          60        RL           68    11250    Pave    NaN
# 4        4          70        RL           60     9550    Pave    NaN
# ...    ...         ...       ...          ...      ...     ...    ...
# 1456  1456          60        RL           62     7917    Pave    NaN
# 1457  1457          20        RL           85    13175    Pave    NaN
# 1458  1458          70        RL           66     9042    Pave    NaN
# 1459  1459          20        RL           68     9717    Pave    NaN
# 1460  1460          20        RL           75     9937    Pave    NaN
#
#             7            8          9   ...        71      72     73  \
# ...

# %%
summeroly16 = pd.read_html('https://en.wikipedia.org/wiki/2016_Summer_Olympics_medal_table')
summeroly16
# Out:
# [               2016 Summer Olympics medals  \
#  0                                 Location
#  1                               Highlights
#  2                         Most gold medals
#  3                        Most total medals
#  4  ← 2012 · Olympics medal tables · 2020 →
#  5                                 ← 2012 ·
#
#               2016 Summer Olympics medals.1 Unnamed: 2
#  0                   Rio de Janeiro, Brazil        NaN
#  1                               Highlights        NaN
#  2                       United States (46)        NaN
#  3                      United States (121)        NaN
#  4  ← 2012 · Olympics medal tables · 2020 →        NaN
#  5                    Olympics medal tables   · 2020 →  ,
#            0                      1         2
#  0  ← 2012 ·  Olympics medal tables  · 2020 →,
#                                                     0
#  0                                Part of a series on
#  1                               2016 Summer Olympics
# ...

# %%
len(summeroly16)
# Out:
# 8

# %%
targettable = pd.DataFrame(summeroly16[3])
print(targettable)
# Out:
#                    Rank                   NOC  Gold  Silver  Bronze  Total
# 0                     1         United States    46      37      38    121
# 1                     2         Great Britain    27      23      17     67
# 2                     3                 China    26      18      26     70
# 3                     4                Russia    19      17      20     56
# 4                     5               Germany    17      10      15     42
# ..                  ...                   ...   ...     ...     ...    ...
# 82                   78               Nigeria     0       0       1      1
# 83                   78              Portugal     0       0       1      1
# 84                   78   Trinidad and Tobago     0       0       1      1
# 85                   78  United Arab Emirates     0       0       1      1
# 86  Totals (86 entries)   Totals (86 entries)   306     307     359    972
#
# [87 rows x 6 columns]

# %%
print(targettable[:20])
# Out:
#    Rank            NOC  Gold  Silver  Bronze  Total
# 0     1  United States    46      37      38    121
# 1     2  Great Britain    27      23      17     67
# 2     3          China    26      18      26     70
# 3     4         Russia    19      17      20     56
# 4     5        Germany    17      10      15     42
# 5     6          Japan    12       8      21     41
# 6     7         France    10      18      14     42
# 7     8    South Korea     9       3       9     21
# 8     9          Italy     8      12       8     28
# 9    10      Australia     8      11      10     29
# 10   11    Netherlands     8       7       4     19
# 11   12        Hungary     8       3       4     15
# 12   13        Brazil*     7       6       6     19
# 13   14          Spain     7       4       6     17
# 14   15          Kenya     6       6       1     13
# 15   16        Jamaica     6       3       2     11
# 16   17        Croatia     5       3       2     10
# ...
